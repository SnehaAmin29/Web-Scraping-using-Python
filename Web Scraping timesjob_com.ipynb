# %%
from bs4 import BeautifulSoup

# %%
# import requests it will req info from sites as a real person requesting for info
# 
import requests

# %%
# at the end of get method write text to get content 
#else it will just give success resp code 200
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=').text
print(html_text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <head>
#
#
# 	<link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet">
# 		<link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
#        <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
#       	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js"></script>
# ...

# %%
soup = BeautifulSoup(html_text, 'lxml')

# %% [markdown]
# **This is for one job post

# %%
job = soup.find('li', class_ = 'clearfix job-bx wht-shd-bx')
print(job) #this will fetch the list with class specified in html format
# Out:
# <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-virtusa-consulting-services-pvt-ltd-pune-6-to-9-yrs-jobid-Reaxnq7jZr9zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70504133','python programming   ,   data analysis   ,   data visualization   ,   database management   ,   requirements gathering   ,  data mining  ,  sql','Pune','6 - 9','IT Software : Software Products &amp; Services','1','' )" target="_blank">
# <strong class="blkclor">Python</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     virtusa consulting services pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>6 - 9 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune">Pune</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# ...

# %%
company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ', '')
print(company_name)
# Out:
# virtusaconsultingservicespvt.ltd.

# %%
skills = job.find('span', class_ = 'srp-skills').text.replace(' ', '')
print(skills)
# Out:
# pythonprogramming,dataanalysis,datavisualization,databasemanagement,requirementsgathering,datamining,sql

# %%
published_date = job.find('span', class_ = 'sim-posted').span.text
print(published_date)
# Out:
# Posted few days ago

# %%
print(f'''
Company Name: {company_name}
Required Skills : {skills}
''')
# Out:
# Company Name:
# virtusaconsultingservicespvt.ltd.
#
#
# Required Skills :
# pythonprogramming,dataanalysis,datavisualization,databasemanagement,requirementsgathering,datamining,sql

# %% [markdown]
# Now if want same thing for multiple job post then

# %%
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')

for job in jobs:
    published_date = job.find('span', class_ = 'sim-posted').span.text
    if 'few' in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ', '')
        skills = job.find('span', class_ = 'srp-skills').text.replace(' ', '')

        print(f'''
        Company Name: {company_name}
        Required Skills : {skills}
        ''')
# Out:
#         Company Name:
# virtusaconsultingservicespvt.ltd.
#
#
#         Required Skills :
# pythonprogramming,dataanalysis,datavisualization,databasemanagement,requirementsgathering,datamining,sql
#
#
#
#
#         Company Name:
# virtusaconsultingservicespvt.ltd.
#
#
#         Required Skills :
# python,javascript,sql,restfulwebservices,systemdesign,css,git,html
#
#
#
#
#         Company Name:
# SEVENCONSULTANCY
#
#
#         Required Skills :
# python,mvc,sql
#
#
#
#
#         Company Name:
# CONNECTING2WORK
#
#
#         Required Skills :
#
# rest,python,django,mongodb
#
#
#
#
#         Company Name:
# eastindiasecuritiesltd.
#
#
#         Required Skills :
# python,hadoop,machinelearning
#
#
#
#
#         Company Name:
# LAKSHHUMANRESOURCE
#
#
#         Required Skills :
#
# rest,python,django,git
#
#
#
#
#         Company Name:
# arttechnologyandsoftwareindiapvtltd
#
#
#         Required Skills :
#
# rest,python,database,django,api
#
#
#
#
#         Company Name:
# zengatv
#
#
# ...

# %%
Overview

# %%
from bs4 import BeautifulSoup
import requests



html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')

for job in jobs:
    published_date = job.find('span', class_ = 'sim-posted').span.text
    if 'few' in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ', '')
        skills = job.find('span', class_ = 'srp-skills').text.replace(' ', '')
        more_info = job.header.h2.a['href']

        print(f"Company Name: {company_name.strip()}") #used strip method to remove blank space after text
        print(f"Required Skills: {skills.strip()}")
        print(f"Job Description: {more_info}")
        
        print(' ')
# Out:
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: pythonprogramming,dataanalysis,datavisualization,databasemanagement,requirementsgathering,datamining,sql
# Job Description: https://www.timesjobs.com/job-detail/python-virtusa-consulting-services-pvt-ltd-pune-6-to-9-yrs-jobid-Reaxnq7jZr9zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: python,javascript,sql,restfulwebservices,systemdesign,css,git,html
# Job Description: https://www.timesjobs.com/job-detail/python-virtusa-consulting-services-pvt-ltd-3-to-5-yrs-jobid-pVT1BiWg5ERzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: SEVENCONSULTANCY
# Required Skills: python,mvc,sql
# Job Description: https://www.timesjobs.com/job-detail/python-developer-seven-consultancy-navi-mumbai-mumbai-4-to-7-yrs-jobid-__PLUS__FcvQeiaCFlzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: CONNECTING2WORK
# Required Skills: rest,python,django,mongodb
# ...
